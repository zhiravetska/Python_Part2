# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
from getpass import getpass

# %%
#Authentication

cid = getpass("Client ID: ")
secret = getpass("Client secret: ")

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="cid", client_secret="secret")
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF"
playlist_URI = playlist_link.split("/")[-1].split("?")[0]
track_uris = [x["track"]["uri"] for x in sp.playlist_tracks(playlist_URI)["items"]]
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\spotipy\oauth2.py:265, in SpotifyClientCredentials._request_access_token(self)
#     257 response = self._session.post(
#     258     self.OAUTH_TOKEN_URL,
#     259     data=payload,
#    (...)
#     263     timeout=self.requests_timeout,
#     264 )
# --> 265 response.raise_for_status()
#     266 token_info = response.json()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://accounts.spotify.com/api/token
#
# During handling of the above exception, another exception occurred:
#
# SpotifyOauthError                         Traceback (most recent call last)
# Cell In [18], line 3
#       1 playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF"
#       2 playlist_URI = playlist_link.split("/")[-1].split("?")[0]
# ----> 3 track_uris = [x["track"]["uri"] for x in sp.playlist_tracks(playlist_URI)["items"]]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\spotipy\client.py:683, in Spotify.playlist_tracks(self, playlist_id, fields, limit, offset, market, additional_types)
#     667 """ Get full details of the tracks of a playlist.
#     668
#     669     Parameters:
#    (...)
#     676                              valid types are: track and episode
#     677 """
#     678 warnings.warn(
#     679     "You should use `playlist_items(playlist_id, ...,"
#     680     "additional_types=('track',))` instead",
#     681     DeprecationWarning,
#     682 )
# --> 683 return self.playlist_items(playlist_id, fields, limit, offset,
#     684                            market, additional_types)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\spotipy\client.py:707, in Spotify.playlist_items(self, playlist_id, fields, limit, offset, market, additional_types)
#     695 """ Get full details of the tracks and episodes of a playlist.
#     696
#     697     Parameters:
#    (...)
#     704                              valid types are: track and episode
#     705 """
#     706 plid = self._get_id("playlist", playlist_id)
# --> 707 return self._get(
#     708     "playlists/%s/tracks" % (plid),
#     709     limit=limit,
#     710     offset=offset,
#     711     fields=fields,
#     712     market=market,
#     713     additional_types=",".join(additional_types)
#     714 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\spotipy\client.py:323, in Spotify._get(self, url, args, payload, **kwargs)
#     320 if args:
#     321     kwargs.update(args)
# --> 323 return self._internal_call("GET", url, payload, kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\spotipy\client.py:247, in Spotify._internal_call(self, method, url, payload, params)
#     245 if not url.startswith("http"):
#     246     url = self.prefix + url
# --> 247 headers = self._auth_headers()
#     249 if "content_type" in args["params"]:
#     250     headers["Content-Type"] = args["params"]["content_type"]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\spotipy\client.py:238, in Spotify._auth_headers(self)
#     236     return {}
#     237 try:
# --> 238     token = self.auth_manager.get_access_token(as_dict=False)
#     239 except TypeError:
#     240     token = self.auth_manager.get_access_token()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\spotipy\oauth2.py:238, in SpotifyClientCredentials.get_access_token(self, as_dict, check_cache)
#     235     if token_info and not self.is_token_expired(token_info):
#     236         return token_info if as_dict else token_info["access_token"]
# --> 238 token_info = self._request_access_token()
#     239 token_info = self._add_custom_values_to_token_info(token_info)
#     240 self.cache_handler.save_token_to_cache(token_info)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\spotipy\oauth2.py:269, in SpotifyClientCredentials._request_access_token(self)
#     267     return token_info
#     268 except requests.exceptions.HTTPError as http_error:
# --> 269     self._handle_oauth_error(http_error)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\spotipy\oauth2.py:146, in SpotifyAuthBase._handle_oauth_error(self, http_error)
#     143     error = response.text or None
#     144     error_description = None
# --> 146 raise SpotifyOauthError(
#     147     'error: {0}, error_description: {1}'.format(
#     148         error, error_description
#     149     ),
#     150     error=error,
#     151     error_description=error_description
#     152 )
#
# SpotifyOauthError: error: invalid_client, error_description: Invalid client

# %%
track_uris
# Out:
# ['spotify:track:7x9aauaA9cu6tyfpHnqDLo',
#  'spotify:track:2IGMVunIBsBLtEQyoI1Mu7',
#  'spotify:track:1BxfuPKGuaTgP7aM0Bbdwr',
#  'spotify:track:7ABLbnD53cQK00mhcaOUVG',
#  'spotify:track:5RqSsdzTNPX1uzkmlHCFvK',
#  'spotify:track:6wf7Yu7cxBSPrRlWeSeK0Q',
#  'spotify:track:1vYXt7VSjH9JIM5oRRo7vA',
#  'spotify:track:6XbtvPmIpyCbjuT0e8cQtp',
#  'spotify:track:1kuGVB7EU95pJObxwvfwKS',
#  'spotify:track:4rXLjWdF2ZZpXCVTfWcshS',
#  'spotify:track:2FDTHlrBguDzQkp7PVj16Q',
#  'spotify:track:1odExI7RdWc4BT515LTAwj',
#  'spotify:track:7mXuWTczZNxG5EDcjFEuJR',
#  'spotify:track:4Dvkj6JhhA12EX05fT7y2e',
#  'spotify:track:4DHcnVTT87F0zZhRPYmZ3B',
#  'spotify:track:1Qrg8KqiBpW07V7PNxwwwL',
#  'spotify:track:741UUVE2kuITl0c6zuqqbO',
#  'spotify:track:5sdQOyqq2IDhvmx2lHOpwd',
#  'spotify:track:5XeFesFbtLpXzIVDNQP22n',
#  'spotify:track:4KULAymBBJcPRpk1yO4dOG',
#  'spotify:track:7ro0hRteUMfnOioTFI5TG1',
#  'spotify:track:6XSqqQIy7Lm7SnwxS4NrGx',
#  'spotify:track:25OeKzcqakFPaJlXHPE5lm',
#  'spotify:track:2UW7JaomAMuX9pZrjVpHAU',
#  'spotify:track:23RoR84KodL5HWvUTneQ1w',
#  'spotify:track:54zcJnb3tp9c5OVKREZ1Is',
#  'spotify:track:3hUxzQpSfdDqwM3ZTFQY0K',
#  'spotify:track:3IX0yuEVvDbnqUwMBB3ouC',
#  'spotify:track:6irysuQyZWd7Bjj7ePiOs2',
#  'spotify:track:59NraMJsLaMCVtwXTSia8i',
#  'spotify:track:6WzRpISELf3YglGAh7TXcG',
#  'spotify:track:4lIxdJw6W3Fg4vUIYCB0S5',
#  'spotify:track:5PUXKVVVQ74C3gl5vKy9Li',
#  'spotify:track:6uIIdjYTxxpWOyWuVXrKQO',
#  'spotify:track:1p80LdxRV74UKvL8gnD7ky',
#  'spotify:track:41WQUSINanQHfhfKpFDsms',
#  'spotify:track:0V3wPSX9ygBnCm8psDIegu',
#  'spotify:track:3qQbCzHBycnDpGskqOWY0E',
#  'spotify:track:2N0SPREDYqILVEFSsWF5N5',
#  'spotify:track:3Ua0m0YmEjrMi9XErKcNiR',
#  'spotify:track:7MXVkk9YMctZqd1Srtv4MB',
#  'spotify:track:2LBqCSwhJGcFQeTHMVGwy3',
#  'spotify:track:6wsqVwoiVH2kde4k4KKAFU',
#  'spotify:track:1s7oOCT8vauUh01PbJD6ps',
#  'spotify:track:67nepsnrcZkowTxMWigSbb',
#  'spotify:track:7K3BhSpAxZBznislvUMVtn',
#  'spotify:track:2yzshFeBIwH8tWIqHEFLeD',
#  'spotify:track:2dHHgzDwk4BJdRwy9uXhTO',
#  'spotify:track:7bPp2NmpmyhLJ7zWazAXMu',
#  'spotify:track:7FbrGaHYVDmfr7KoLIZnQ7']

# %%
trackuri = []
tname = []
artisturi = []
artistinfo = []
artname = []
artpop = []
artgenres = []
albumname = []
tpop = []

# %%
for track in sp.playlist_tracks(playlist_URI)["items"]:
    #URI
    track_uri = track["track"]["uri"]
    
    #Track name
    track_name = track["track"]["name"]
    
    #Main Artist
    artist_uri = track["track"]["artists"][0]["uri"]
    artist_info = sp.artist(artist_uri)
   # artist_info = sp.artist(track["track"]["artists"][0]["uri"])
    
    #Name, popularity, genre
    artist_name = track["track"]["artists"][0]["name"]
    artist_pop = artist_info["popularity"]
    artist_info["genres"]
    
    #Album
    album = track["track"]["album"]["name"]
    
    #Popularity of the track
    track_pop = track["track"]["popularity"]
    
#track_uri 
track_name 
#artist_uri 
#artist_info 
artist_name 
artist_pop 
artist_info 
album 
track_pop
# Out:
# 93

# %%
for track in sp.playlist_tracks(playlist_URI)["items"]:
    trackuri.append(track["track"]["uri"])
    tname.append(track["track"]["name"])
    artisturi.append(track["track"]["artists"][0]["uri"])
    artistinfo.append(sp.artist(artist_uri))
    artname.append(track["track"]["artists"][0]["name"])
    artpop.append(artist_info["popularity"])
    artgenres.append(artist_info["genres"])
    albumname.append(track["track"]["album"]["name"])
    #tpop.append(track["track"]["popularity"])

# %%
data = {"Track_URI": trackuri,
        "Track Name": tname,
        "Artist URI": artisturi,
        "Artist Info": artistinfo,
        "Artist Name": artname, 
        "Artist Pop": artpop, 
        "Genres": artgenres,
        "Album": albumname}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                Track_URI  \
# 0   spotify:track:7x9aauaA9cu6tyfpHnqDLo
# 1   spotify:track:2IGMVunIBsBLtEQyoI1Mu7
# 2   spotify:track:1BxfuPKGuaTgP7aM0Bbdwr
# 3   spotify:track:7ABLbnD53cQK00mhcaOUVG
# 4   spotify:track:5RqSsdzTNPX1uzkmlHCFvK
# 5   spotify:track:6wf7Yu7cxBSPrRlWeSeK0Q
# 6   spotify:track:1vYXt7VSjH9JIM5oRRo7vA
# 7   spotify:track:6XbtvPmIpyCbjuT0e8cQtp
# 8   spotify:track:1kuGVB7EU95pJObxwvfwKS
# 9   spotify:track:4rXLjWdF2ZZpXCVTfWcshS
# 10  spotify:track:2FDTHlrBguDzQkp7PVj16Q
# 11  spotify:track:1odExI7RdWc4BT515LTAwj
# 12  spotify:track:7mXuWTczZNxG5EDcjFEuJR
# 13  spotify:track:4Dvkj6JhhA12EX05fT7y2e
# 14  spotify:track:4DHcnVTT87F0zZhRPYmZ3B
# 15  spotify:track:1Qrg8KqiBpW07V7PNxwwwL
# 16  spotify:track:741UUVE2kuITl0c6zuqqbO
# 17  spotify:track:5sdQOyqq2IDhvmx2lHOpwd
# 18  spotify:track:5XeFesFbtLpXzIVDNQP22n
# 19  spotify:track:4KULAymBBJcPRpk1yO4dOG
# 20  spotify:track:7ro0hRteUMfnOioTFI5TG1
# 21  spotify:track:6XSqqQIy7Lm7SnwxS4NrGx
# 22  spotify:track:25OeKzcqakFPaJlXHPE5lm
# 23  spotify:track:2UW7JaomAMuX9pZrjVpHAU
# 24  spotify:track:23RoR84KodL5HWvUTneQ1w
# 25  spotify:track:54zcJnb3tp9c5OVKREZ1Is
# 26  spotify:track:3hUxzQpSfdDqwM3ZTFQY0K
# 27  spotify:track:3IX0yuEVvDbnqUwMBB3ouC
# 28  spotify:track:6irysuQyZWd7Bjj7ePiOs2
# 29  spotify:track:59NraMJsLaMCVtwXTSia8i
# 30  spotify:track:6WzRpISELf3YglGAh7TXcG
# 31  spotify:track:4lIxdJw6W3Fg4vUIYCB0S5
# 32  spotify:track:5PUXKVVVQ74C3gl5vKy9Li
# 33  spotify:track:6uIIdjYTxxpWOyWuVXrKQO
# 34  spotify:track:1p80LdxRV74UKvL8gnD7ky
# 35  spotify:track:41WQUSINanQHfhfKpFDsms
# 36  spotify:track:0V3wPSX9ygBnCm8psDIegu
# 37  spotify:track:3qQbCzHBycnDpGskqOWY0E
# 38  spotify:track:2N0SPREDYqILVEFSsWF5N5
# 39  spotify:track:3Ua0m0YmEjrMi9XErKcNiR
# 40  spotify:track:7MXVkk9YMctZqd1Srtv4MB
# 41  spotify:track:2LBqCSwhJGcFQeTHMVGwy3
# 42  spotify:track:6wsqVwoiVH2kde4k4KKAFU
# 43  spotify:track:1s7oOCT8vauUh01PbJD6ps
# 44  spotify:track:67nepsnrcZkowTxMWigSbb
# 45  spotify:track:7K3BhSpAxZBznislvUMVtn
# 46  spotify:track:2yzshFeBIwH8tWIqHEFLeD
# 47  spotify:track:2dHHgzDwk4BJdRwy9uXhTO
# 48  spotify:track:7bPp2NmpmyhLJ7zWazAXMu
# 49  spotify:track:7FbrGaHYVDmfr7KoLIZnQ7
#
#                                            Track Name  \
# 0                 Seven (feat. Latto) (Explicit Ver.)
# 1                                  Paint The Town Red
# 2                                        Cruel Summer
# 3                                                LALA
# 4                                               QLONA
# 5   What Was I Made For? [From The Motion Picture ...
# 6             Dance The Night - From Barbie The Album
# 7                                            Columbia
# 8                                             vampire
# 9                                            fukumean
# 10                                           Sprinter
# 11                                           Daylight
# 12                                          LADY GAGA
# 13                                          As It Was
# 14                                            Flowers
# 15                                          Kill Bill
# 16   Barbie World (with Aqua) [From Barbie The Album]
# 17                                          Super Shy
# 18                                   I Wanna Be Yours
# 19      I Remember Everything (feat. Kacey Musgraves)
# 20                                     WHERE SHE GOES
# 21                                         Classy 101
# 22                                       Primera Cita
# 23                                    La Bebe - Remix
# 24                       (It Goes Like) Nanana - Edit
# 25                                  MI EX TENÍA RAZÓN
# 26                                             august
# 27                                    bad idea right?
# 28                                            Holanda
# 29                                              Prada
# 30  Popular (with Playboi Carti & Madonna) - Music...
# 31                                              Style
# 32                       Heeriye (feat. Arijit Singh)
# 33                                           Que Onda
# 34                                        Blank Space
# 35                                   Used To Be Young
# 36                                          Anti-Hero
# 37                                    Ella Baila Sola
# 38                                      Love Me Again
# 39                                         Like Crazy
# 40                                            Starboy
# 41                                        Die For You
# 42                                           I KNOW ?
# 43                      Calm Down (with Selena Gomez)
# 44                             MELTDOWN (feat. Drake)
# 45                                         Last Night
# 46                                          un x100to
# 47             Creepin' (with The Weeknd & 21 Savage)
# 48                                              TULUM
# 49                                  Cupid - Twin Ver.
#
#                                Artist URI  \
# 0   spotify:artist:6HaGTQPmzraVmaVxvz6EUc
# 1   spotify:artist:5cj0lLjcoR7YOSnhnX0Po5
# 2   spotify:artist:06HL4z0CvFAxyc27GXpf02
# 3   spotify:artist:7iK8PXO48WeuP03g8YR51W
# 4   spotify:artist:790FomKkXshlbRYZFtlgla
# 5   spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH
# 6   spotify:artist:6M2wZ9GZgrQXHCFfjv46we
# 7   spotify:artist:52iwsT98xCoGgiGntTiR7K
# 8   spotify:artist:1McMsnEElThX1knmY4oliG
# 9   spotify:artist:2hlmm7s2ICUX0LVIhVFlZQ
# 10  spotify:artist:6Ip8FS7vWT1uKkJSweANQK
# 11  spotify:artist:33NVpKoXjItPwUJTMZIOiY
# 12  spotify:artist:12GqGscKJx3aE4t07u7eVZ
# 13  spotify:artist:6KImCVD70vtIoJWnq6nGn3
# 14  spotify:artist:5YGY8feqx7naU7z4HrwZM6
# 15  spotify:artist:7tYKF4w9nC0nq9CsPZTHyP
# 16  spotify:artist:0hCNtLu0JehylgoiP8L4Gh
# 17  spotify:artist:6HvZYsbFfjnjFrWF950C9d
# 18  spotify:artist:7Ln80lUS6He07XvHI8qqHH
# 19  spotify:artist:40ZNYROS4zLfyyBSs2PGe2
# 20  spotify:artist:4q3ewBCX7sLwd24euuV69X
# 21  spotify:artist:2LRoIwlKmHjgvigdNGBHNo
# 22  spotify:artist:66ihevNkSYNzRAl44dx6jJ
# 23  spotify:artist:1NNRWkhwmcXRimFYSBpB1y
# 24  spotify:artist:2mLA48B366zkELXYx7hcDN
# 25  spotify:artist:790FomKkXshlbRYZFtlgla
# 26  spotify:artist:06HL4z0CvFAxyc27GXpf02
# 27  spotify:artist:1McMsnEElThX1knmY4oliG
# 28  spotify:artist:6nVcHLIgY5pE2YCl8ubca1
# 29  spotify:artist:5wCmhq5J2hPwL2r0eKurxn
# 30  spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ
# 31  spotify:artist:06HL4z0CvFAxyc27GXpf02
# 32  spotify:artist:74OaRjmyh0XyRZsQQQ5l7c
# 33  spotify:artist:6dLuQ5qXxIuWc5urxfIiZR
# 34  spotify:artist:06HL4z0CvFAxyc27GXpf02
# 35  spotify:artist:5YGY8feqx7naU7z4HrwZM6
# 36  spotify:artist:06HL4z0CvFAxyc27GXpf02
# 37  spotify:artist:0XeEobZplHxzM9QzFQWLiR
# 38  spotify:artist:3JsHnjpbhX4SnySpvpa9DK
# 39  spotify:artist:1oSPZhvZMIrWW5I41kPkkY
# 40  spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ
# 41  spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ
# 42  spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY
# 43  spotify:artist:46pWGuE3dSwY3bMMXGBvVS
# 44  spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY
# 45  spotify:artist:4oUHIQIBe0LHzYfvXNW4QM
# 46  spotify:artist:6XkjpgcEsYab502Vr1bBeW
# 47  spotify:artist:0iEtIxbK0KxaSlF7G42ZOp
# 48  spotify:artist:12GqGscKJx3aE4t07u7eVZ
# 49  spotify:artist:4GJ6xDCF5jaUqD6avOuQT6
#
#                                           Artist Info     Artist Name  \
# 0   {'external_urls': {'spotify': 'https://open.sp...       Jung Kook
# 1   {'external_urls': {'spotify': 'https://open.sp...        Doja Cat
# 2   {'external_urls': {'spotify': 'https://open.sp...    Taylor Swift
# 3   {'external_urls': {'spotify': 'https://open.sp...     Myke Towers
# 4   {'external_urls': {'spotify': 'https://open.sp...         KAROL G
# 5   {'external_urls': {'spotify': 'https://open.sp...   Billie Eilish
# 6   {'external_urls': {'spotify': 'https://open.sp...        Dua Lipa
# 7   {'external_urls': {'spotify': 'https://open.sp...         Quevedo
# 8   {'external_urls': {'spotify': 'https://open.sp...  Olivia Rodrigo
# 9   {'external_urls': {'spotify': 'https://open.sp...           Gunna
# 10  {'external_urls': {'spotify': 'https://open.sp...            Dave
# 11  {'external_urls': {'spotify': 'https://open.sp...   David Kushner
# 12  {'external_urls': {'spotify': 'https://open.sp...      Peso Pluma
# 13  {'external_urls': {'spotify': 'https://open.sp...    Harry Styles
# 14  {'external_urls': {'spotify': 'https://open.sp...     Miley Cyrus
# 15  {'external_urls': {'spotify': 'https://open.sp...             SZA
# 16  {'external_urls': {'spotify': 'https://open.sp...     Nicki Minaj
# 17  {'external_urls': {'spotify': 'https://open.sp...        NewJeans
# 18  {'external_urls': {'spotify': 'https://open.sp...  Arctic Monkeys
# 19  {'external_urls': {'spotify': 'https://open.sp...      Zach Bryan
# 20  {'external_urls': {'spotify': 'https://open.sp...       Bad Bunny
# 21  {'external_urls': {'spotify': 'https://open.sp...            Feid
# 22  {'external_urls': {'spotify': 'https://open.sp...      Carin Leon
# 23  {'external_urls': {'spotify': 'https://open.sp...       Yng Lvcas
# 24  {'external_urls': {'spotify': 'https://open.sp...       Peggy Gou
# 25  {'external_urls': {'spotify': 'https://open.sp...         KAROL G
# 26  {'external_urls': {'spotify': 'https://open.sp...    Taylor Swift
# 27  {'external_urls': {'spotify': 'https://open.sp...  Olivia Rodrigo
# 28  {'external_urls': {'spotify': 'https://open.sp...          Jhayco
# 29  {'external_urls': {'spotify': 'https://open.sp...           cassö
# 30  {'external_urls': {'spotify': 'https://open.sp...      The Weeknd
# 31  {'external_urls': {'spotify': 'https://open.sp...    Taylor Swift
# 32  {'external_urls': {'spotify': 'https://open.sp...   Jasleen Royal
# 33  {'external_urls': {'spotify': 'https://open.sp...        Calle 24
# 34  {'external_urls': {'spotify': 'https://open.sp...    Taylor Swift
# 35  {'external_urls': {'spotify': 'https://open.sp...     Miley Cyrus
# 36  {'external_urls': {'spotify': 'https://open.sp...    Taylor Swift
# 37  {'external_urls': {'spotify': 'https://open.sp...  Eslabon Armado
# 38  {'external_urls': {'spotify': 'https://open.sp...               V
# 39  {'external_urls': {'spotify': 'https://open.sp...           Jimin
# 40  {'external_urls': {'spotify': 'https://open.sp...      The Weeknd
# 41  {'external_urls': {'spotify': 'https://open.sp...      The Weeknd
# 42  {'external_urls': {'spotify': 'https://open.sp...    Travis Scott
# 43  {'external_urls': {'spotify': 'https://open.sp...            Rema
# 44  {'external_urls': {'spotify': 'https://open.sp...    Travis Scott
# 45  {'external_urls': {'spotify': 'https://open.sp...   Morgan Wallen
# 46  {'external_urls': {'spotify': 'https://open.sp...  Grupo Frontera
# 47  {'external_urls': {'spotify': 'https://open.sp...    Metro Boomin
# 48  {'external_urls': {'spotify': 'https://open.sp...      Peso Pluma
# 49  {'external_urls': {'spotify': 'https://open.sp...     FIFTY FIFTY
#
#     Artist Pop              Genres  \
# 0           75  [k-pop girl group]
# 1           75  [k-pop girl group]
# 2           75  [k-pop girl group]
# 3           75  [k-pop girl group]
# 4           75  [k-pop girl group]
# 5           75  [k-pop girl group]
# 6           75  [k-pop girl group]
# 7           75  [k-pop girl group]
# 8           75  [k-pop girl group]
# 9           75  [k-pop girl group]
# 10          75  [k-pop girl group]
# 11          75  [k-pop girl group]
# 12          75  [k-pop girl group]
# 13          75  [k-pop girl group]
# 14          75  [k-pop girl group]
# 15          75  [k-pop girl group]
# 16          75  [k-pop girl group]
# 17          75  [k-pop girl group]
# 18          75  [k-pop girl group]
# 19          75  [k-pop girl group]
# 20          75  [k-pop girl group]
# 21          75  [k-pop girl group]
# 22          75  [k-pop girl group]
# 23          75  [k-pop girl group]
# 24          75  [k-pop girl group]
# 25          75  [k-pop girl group]
# 26          75  [k-pop girl group]
# 27          75  [k-pop girl group]
# 28          75  [k-pop girl group]
# 29          75  [k-pop girl group]
# 30          75  [k-pop girl group]
# 31          75  [k-pop girl group]
# 32          75  [k-pop girl group]
# 33          75  [k-pop girl group]
# 34          75  [k-pop girl group]
# 35          75  [k-pop girl group]
# 36          75  [k-pop girl group]
# 37          75  [k-pop girl group]
# 38          75  [k-pop girl group]
# 39          75  [k-pop girl group]
# 40          75  [k-pop girl group]
# 41          75  [k-pop girl group]
# 42          75  [k-pop girl group]
# 43          75  [k-pop girl group]
# 44          75  [k-pop girl group]
# 45          75  [k-pop girl group]
# 46          75  [k-pop girl group]
# 47          75  [k-pop girl group]
# 48          75  [k-pop girl group]
# 49          75  [k-pop girl group]
#
#                                                 Album
# 0                                 Seven (feat. Latto)
# 1                                  Paint The Town Red
# 2                                               Lover
# 3                                      LA VIDA ES UNA
# 4                 MAÑANA SERÁ BONITO (BICHOTA SEASON)
# 5   What Was I Made For? [From The Motion Picture ...
# 6             Dance The Night (From Barbie The Album)
# 7                                            Columbia
# 8                                                GUTS
# 9                                    a Gift & a Curse
# 10                                           Sprinter
# 11                                           Daylight
# 12                                            GÉNESIS
# 13                                      Harry's House
# 14                            Endless Summer Vacation
# 15                                                SOS
# 16   Barbie World (with Aqua) [From Barbie The Album]
# 17                               NewJeans 'Super Shy'
# 18                                                 AM
# 19                                         Zach Bryan
# 20                                     WHERE SHE GOES
# 21                                         Classy 101
# 22                                  Colmillo De Leche
# 23                                    La Bebe (Remix)
# 24                       (It Goes Like) Nanana [Edit]
# 25                MAÑANA SERÁ BONITO (BICHOTA SEASON)
# 26                                           folklore
# 27                                               GUTS
# 28                                            Holanda
# 29                                              Prada
# 30       Popular (Music from the HBO Original Series)
# 31                                               1989
# 32                       Heeriye (feat. Arijit Singh)
# 33                                           Que Onda
# 34                                               1989
# 35                            Endless Summer Vacation
# 36                                          Midnights
# 37                                          DESVELADO
# 38                                            Layover
# 39                                               FACE
# 40                                            Starboy
# 41                                            Starboy
# 42                                             UTOPIA
# 43                                 Rave & Roses Ultra
# 44                                             UTOPIA
# 45                                One Thing At A Time
# 46                                        El Comienzo
# 47                                  HEROES & VILLAINS
# 48                                            GÉNESIS
# 49                               The Beginning: Cupid

# %%
artists_names = df['Artist Name'].unique()

# %%
print(artists_names)
# Out:
# ['Jung Kook' 'Doja Cat' 'Taylor Swift' 'Myke Towers' 'KAROL G'
#  'Billie Eilish' 'Dua Lipa' 'Quevedo' 'Olivia Rodrigo' 'Gunna' 'Dave'
#  'David Kushner' 'Peso Pluma' 'Harry Styles' 'Miley Cyrus' 'SZA'
#  'Nicki Minaj' 'NewJeans' 'Arctic Monkeys' 'Zach Bryan' 'Bad Bunny' 'Feid'
#  'Carin Leon' 'Yng Lvcas' 'Peggy Gou' 'Jhayco' 'cassö' 'The Weeknd'
#  'Jasleen Royal' 'Calle 24' 'Eslabon Armado' 'V' 'Jimin' 'Travis Scott'
#  'Rema' 'Morgan Wallen' 'Grupo Frontera' 'Metro Boomin' 'FIFTY FIFTY']

# %%
acoustic = []
dance = []
energy = []
instrumental = []
liveness = []
loudness = []
speech = []
tempo = []
valence = []
popularity = []

for i in trackuri:
    feat = sp.audio_features(i)[0]
    acoustic.append(feat['acousticness'])
    dance.append(feat['danceability'])
    energy.append(feat['energy'])
    speech.append(feat['speechiness'])
    instrumental.append(feat['instrumentalness'])
    loudness.append(feat['loudness'])
    tempo.append(feat['tempo'])
    liveness.append(feat['liveness'])
    valence.append(feat['valence'])
    popu = sp.track(i)
    popularity.append(popu['popularity'])

# %%
ari = pd.DataFrame({'name':track_name,
                    'dance':dance,
                    'acoustic':acoustic,
                    'energy':energy,
                    'instrumental':instrumental,
                    'liveness':liveness,
                    'loudness':loudness,
                    'speech':speech,
                    'tempo':tempo,
                    'valence':valence,
                    'popularity':popularity
    
})
ari.head()
# Out:
#                 name  dance  acoustic  energy  instrumental  liveness  \
# 0  Cupid - Twin Ver.  0.802    0.3110   0.832      0.000000    0.0815
# 1  Cupid - Twin Ver.  0.868    0.2690   0.538      0.000003    0.0901
# 2  Cupid - Twin Ver.  0.552    0.1170   0.702      0.000021    0.1050
# 3  Cupid - Twin Ver.  0.708    0.0739   0.737      0.001620    0.0955
# 4  Cupid - Twin Ver.  0.841    0.5200   0.738      0.000000    0.0892
#
#    loudness  speech    tempo  valence  popularity
# 0    -4.107  0.0434  124.997    0.890          99
# 1    -8.603  0.1740   99.968    0.732          99
# 2    -5.707  0.1570  169.994    0.564         100
# 3    -4.045  0.0436   91.986    0.607          99
# 4    -7.455  0.3070  169.918    0.484          91
