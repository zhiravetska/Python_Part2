# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth 
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
from getpass import getpass

# %%
#spotify = spotipy.Spotify(client_credentials_manager=SpotifyOAuth(client, redirect_uri='http://localhost:8888/',
  #                                                                scope="user-modify-playback-state playlist-read-private"))

# %%
#Authentication

cid = getpass("Client ID: ")
secret = getpass("Client Secret: ")
# Out:
# Client ID: ········
# Client Secret: ········

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF"
playlist_URI = playlist_link.split("/")[-1].split("?")[0]
track_uris = [x["track"]["uri"] for x in sp.playlist_tracks(playlist_URI)["items"]]

# %%
track_uris
# Out:
# ['spotify:track:2IGMVunIBsBLtEQyoI1Mu7',
#  'spotify:track:7x9aauaA9cu6tyfpHnqDLo',
#  'spotify:track:1kuGVB7EU95pJObxwvfwKS',
#  'spotify:track:1BxfuPKGuaTgP7aM0Bbdwr',
#  'spotify:track:3IX0yuEVvDbnqUwMBB3ouC',
#  'spotify:track:2gyxAWHebV7xPYVxqoi86f',
#  'spotify:track:5RqSsdzTNPX1uzkmlHCFvK',
#  'spotify:track:7ABLbnD53cQK00mhcaOUVG',
#  'spotify:track:34sOdxWu9FljH84UXdRwu1',
#  'spotify:track:1vYXt7VSjH9JIM5oRRo7vA',
#  'spotify:track:6wf7Yu7cxBSPrRlWeSeK0Q',
#  'spotify:track:6XbtvPmIpyCbjuT0e8cQtp',
#  'spotify:track:3NVGCgwq4bHB1i2ZHt5rst',
#  'spotify:track:4rXLjWdF2ZZpXCVTfWcshS',
#  'spotify:track:3Nl5OkkmS5DaBZvuYofpAt',
#  'spotify:track:5CscrLqFBgPfZR8fGtikov',
#  'spotify:track:5sp71CUt0jXRNqHblPGp7b',
#  'spotify:track:53dtP2iUMvaF28JZcHnFuU',
#  'spotify:track:6QT6j7rKt7Vk3IuV2AUO9W',
#  'spotify:track:1odExI7RdWc4BT515LTAwj',
#  'spotify:track:7mXuWTczZNxG5EDcjFEuJR',
#  'spotify:track:26QLJMK8G0M06sk7h7Fkse',
#  'spotify:track:2FDTHlrBguDzQkp7PVj16Q',
#  'spotify:track:5XeFesFbtLpXzIVDNQP22n',
#  'spotify:track:4Dvkj6JhhA12EX05fT7y2e',
#  'spotify:track:2N0SPREDYqILVEFSsWF5N5',
#  'spotify:track:1Qrg8KqiBpW07V7PNxwwwL',
#  'spotify:track:4DHcnVTT87F0zZhRPYmZ3B',
#  'spotify:track:5mjYQaktjmjcMKcUIcqz4s',
#  'spotify:track:4KULAymBBJcPRpk1yO4dOG',
#  'spotify:track:6uIIdjYTxxpWOyWuVXrKQO',
#  'spotify:track:5sdQOyqq2IDhvmx2lHOpwd',
#  'spotify:track:6W9l02gRsXVxzIuQC1oc1X',
#  'spotify:track:6XSqqQIy7Lm7SnwxS4NrGx',
#  'spotify:track:7ro0hRteUMfnOioTFI5TG1',
#  'spotify:track:59NraMJsLaMCVtwXTSia8i',
#  'spotify:track:2UW7JaomAMuX9pZrjVpHAU',
#  'spotify:track:3xMHXmedL5Rvfxmiar9Ryv',
#  'spotify:track:741UUVE2kuITl0c6zuqqbO',
#  'spotify:track:25OeKzcqakFPaJlXHPE5lm',
#  'spotify:track:6WzRpISELf3YglGAh7TXcG',
#  'spotify:track:6irysuQyZWd7Bjj7ePiOs2',
#  'spotify:track:5PUXKVVVQ74C3gl5vKy9Li',
#  'spotify:track:7MXVkk9YMctZqd1Srtv4MB',
#  'spotify:track:23RoR84KodL5HWvUTneQ1w',
#  'spotify:track:54zcJnb3tp9c5OVKREZ1Is',
#  'spotify:track:2yzshFeBIwH8tWIqHEFLeD',
#  'spotify:track:4lIxdJw6W3Fg4vUIYCB0S5',
#  'spotify:track:7fesNTgTEMEH0ye8MOgEDY',
#  'spotify:track:1p80LdxRV74UKvL8gnD7ky']

# %%
trackuri = []
tname = []
artisturi = []
artistinfo = []
artname = []
artpop = []
artgenres = []
albumname = []
tpop = []

# %%
for track in sp.playlist_tracks(playlist_URI)["items"]:
    #URI
    track_uri = track 
    
#     #Track name
#     track_name = track["track"]["name"]
    
    #Main Artist
    artist_uri = track["track"]["artists"][0]["uri"]
    artist_info = sp.artist(artist_uri)
   # artist_info = sp.artist(track["track"]["artists"][0]["uri"])
    
    #Name, popularity, genre
    artist_name = track["track"]["artists"][0]["name"]
    artist_pop = artist_info["popularity"]
    artist_info["genres"]
    
    #Album
    album = track["track"]["album"]["name"]
    
    #Popularity of the track
    track_pop = track["track"]["popularity"]
    
#track_uri 
#track_name 
#artist_uri 
#artist_info 
artist_name 
artist_pop 
artist_info 
album 
track_pop
# Out:
# 83

# %%
for track in sp.playlist_tracks(playlist_URI)["items"]:
    trackuri.append(track["track"]["uri"])
    tname.append(track["track"]["name"])
    artisturi.append(track["track"]["artists"][0]["uri"])
    artistinfo.append(sp.artist(artist_uri))
    artname.append(track["track"]["artists"][0]["name"])
    artpop.append(artist_info["popularity"])
    artgenres.append(artist_info["genres"])
    albumname.append(track["track"]["album"]["name"])
    #tpop.append(track["track"]["popularity"])

# %%
data = {"Track_URI": trackuri,
        "Track Name": tname,
        "Artist URI": artisturi,
        "Artist Info": artistinfo,
        "Artist Name": artname, 
        "Artist Pop": artpop, 
        "Genres": artgenres,
        "Album": albumname}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                Track_URI  \
# 0   spotify:track:2IGMVunIBsBLtEQyoI1Mu7
# 1   spotify:track:7x9aauaA9cu6tyfpHnqDLo
# 2   spotify:track:1kuGVB7EU95pJObxwvfwKS
# 3   spotify:track:1BxfuPKGuaTgP7aM0Bbdwr
# 4   spotify:track:3IX0yuEVvDbnqUwMBB3ouC
# 5   spotify:track:2gyxAWHebV7xPYVxqoi86f
# 6   spotify:track:5RqSsdzTNPX1uzkmlHCFvK
# 7   spotify:track:7ABLbnD53cQK00mhcaOUVG
# 8   spotify:track:34sOdxWu9FljH84UXdRwu1
# 9   spotify:track:1vYXt7VSjH9JIM5oRRo7vA
# 10  spotify:track:6wf7Yu7cxBSPrRlWeSeK0Q
# 11  spotify:track:6XbtvPmIpyCbjuT0e8cQtp
# 12  spotify:track:3NVGCgwq4bHB1i2ZHt5rst
# 13  spotify:track:4rXLjWdF2ZZpXCVTfWcshS
# 14  spotify:track:3Nl5OkkmS5DaBZvuYofpAt
# 15  spotify:track:5CscrLqFBgPfZR8fGtikov
# 16  spotify:track:5sp71CUt0jXRNqHblPGp7b
# 17  spotify:track:53dtP2iUMvaF28JZcHnFuU
# 18  spotify:track:6QT6j7rKt7Vk3IuV2AUO9W
# 19  spotify:track:1odExI7RdWc4BT515LTAwj
# 20  spotify:track:7mXuWTczZNxG5EDcjFEuJR
# 21  spotify:track:26QLJMK8G0M06sk7h7Fkse
# 22  spotify:track:2FDTHlrBguDzQkp7PVj16Q
# 23  spotify:track:5XeFesFbtLpXzIVDNQP22n
spotify:artist:06HL4z0CvFAxyc27GXpf02
# 48  spotify:artist:1McMsnEElThX1knmY4oliG
# 49  spotify:artist:06HL4z0CvFAxyc27GXpf02
#
#                                           Artist Info          Artist Name  \
# 0   {'external_urls': {'spotify': 'https://open.sp...             Doja Cat
# 1   {'external_urls': {'spotify': 'https://open.sp...            Jung Kook
# 2   {'external_urls': {'spotify': 'https://open.sp...       Olivia Rodrigo
# 3   {'external_urls': {'spotify': 'https://open.sp...         Taylor Swift
# 4   {'external_urls': {'spotify': 'https://open.sp...       Olivia Rodrigo
# 5   {'external_urls': {'spotify': 'https://open.sp...       Olivia Rodrigo
# 6   {'external_urls': {'spotify': 'https://open.sp...              KAROL G
# 7   {'external_urls': {'spotify': 'https://open.sp...          Myke Towers
# 8   {'external_urls': {'spotify': 'https://open.sp...       Olivia Rodrigo
# 9   {'external_urls': {'spotify': 'https://open.sp...             Dua Lipa
# 10  {'external_urls': {'spotify': 'https://open.sp...        Billie Eilish
# 11  {'external_urls': {'spotify': 'https://open.sp...              Quevedo
# 12  {'external_urls': {'spotify': 'https://open.sp...                    V
# 13  {'external_urls': {'spotify': 'https://open.sp...                Gunna
# 14  {'external_urls': {'spotify': 'https://open.sp...       Olivia Rodrigo
# 15  {'external_urls': {'spotify': 'https://open.sp...       Olivia Rodrigo
# 16  {'external_urls': {'spotify': 'https://open.sp...       Olivia Rodrigo
# 17  {'external_urls': {'spotify': 'https://open.sp...       Olivia Rodrigo
# 18  {'external_urls': {'spotify': 'https://open.sp...       Olivia Rodrigo
# 19  {'external_urls': {'spotify': 'https://open.sp...        David Kushner
# 20  {'external_urls': {'spotify': 'https://open.sp...           Peso Pluma
# 21  {'external_urls': {'spotify': 'https://open.sp...       Olivia Rodrigo
# 22  {'external_urls': {'spotify': 'https://open.sp...                 Dave
# 23  {'external_urls': {'spotify': 'https://open.sp...       Arctic Monkeys
# 24  {'external_urls': {'spotify': 'https://open.sp...         Harry Styles
# 25  {'external_urls': {'spotify': 'https://open.sp...                    V
# 26  {'external_urls': {'spotify': 'https://open.sp...                  SZA
# 27  {'external_urls': {'spotify': 'https://open.sp...          Miley Cyrus
# 28  {'external_urls': {'spotify': 'https://open.sp...          Kenya Grace
# 29  {'external_urls': {'spotify': 'https://open.sp...           Zach Bryan
# 30  {'external_urls': {'spotify': 'https://open.sp...             Calle 24
# 31  {'external_urls': {'spotify': 'https://open.sp...             NewJeans
# 32  {'external_urls': {'spotify': 'https://open.sp...       Olivia Rodrigo
# 33  {'external_urls': {'spotify': 'https://open.sp...                 Feid
# 34  {'external_urls': {'spotify': 'https://open.sp...            Bad Bunny
# 35  {'external_urls': {'spotify': 'https://open.sp...                cassö
# 36  {'external_urls': {'spotify': 'https://open.sp...            Yng Lvcas
# 37  {'external_urls': {'spotify': 'https://open.sp...  Anirudh Ravichander
# 38  {'external_urls': {'spotify': 'https://open.sp...          Nicki Minaj
# 39  {'external_urls': {'spotify': 'https://open.sp...           Carin Leon
# 40  {'external_urls': {'spotify': 'https://open.sp...           The Weeknd
# 41  {'external_urls': {'spotify': 'https://open.sp...               Jhayco
# 42  {'external_urls': {'spotify': 'https://open.sp...        Jasleen Royal
# 43  {'external_urls': {'spotify': 'https://open.sp...           The Weeknd
# 44  {'external_urls': {'spotify': 'https://open.sp...            Peggy Gou
# 45  {'external_urls': {'spotify': 'https://open.sp...              KAROL G
# 46  {'external_urls': {'spotify': 'https://open.sp...       Grupo Frontera
# 47  {'external_urls': {'spotify': 'https://open.sp...         Taylor Swift
# 48  {'external_urls': {'spotify': 'https://open.sp...       Olivia Rodrigo
# 49  {'external_urls': {'spotify': 'https://open.sp...         Taylor Swift
#
#     Artist Pop Genres                                              Album
# 0          100  [pop]                                 Paint The Town Red
# 1          100  [pop]                                Seven (feat. Latto)
# 2          100  [pop]                                               GUTS
# 3          100  [pop]                                              Lover
# 4          100  [pop]                                               GUTS
# 5          100  [pop]                                               GUTS
# 6          100  [pop]                MAÑANA SERÁ BONITO (BICHOTA SEASON)
# 7          100  [pop]                                     LA VIDA ES UNA
# 8          100  [pop]                                               GUTS
# 9          100  [pop]            Dance The Night (From Barbie The Album)
# 10         100  [pop]  What Was I Made For? [From The Motion Picture ...
# 11         100  [pop]                                           Columbia
# 12         100  [pop]                                       Slow Dancing
# 13         100  [pop]                                   a Gift & a Curse
# 14         100  [pop]                                               GUTS
# 15         100  [pop]                                               GUTS
# 16         100  [pop]                                               GUTS
# 17         100  [pop]                                               GUTS
# 18         100  [pop]                                               GUTS
# 19         100  [pop]                                           Daylight
# 20         100  [pop]                                            GÉNESIS
# 21         100  [pop]                                               GUTS
# 22         100  [pop]                                           Sprinter
# 23         100  [pop]                                                 AM
# 24         100  [pop]                                      Harry's House
# 25         100  [pop]                                            Layover
# 26         100  [pop]                                                SOS
# 27         100  [pop]                            Endless Summer Vacation
# 28         100  [pop]                                          Strangers
# 29         100  [pop]                                         Zach Bryan
# 30         100  [pop]                                           Que Onda
# 31         100  [pop]                               NewJeans 'Super Shy'
# 32         100  [pop]                                               GUTS
# 33         100  [pop]                                         Classy 101
# 34         100  [pop]                                     WHERE SHE GOES
# 35         100  [pop]                                              Prada
# 36         100  [pop]                                    La Bebe (Remix)
# 37         100  [pop]                                              Jawan
# 38         100  [pop]   Barbie World (with Aqua) [From Barbie The Album]
# 39         100  [pop]                                  Colmillo De Leche
# 40         100  [pop]       Popular (Music from the HBO Original Series)
# 41         100  [pop]                                            Holanda
# 42         100  [pop]                       Heeriye (feat. Arijit Singh)
# 43         100  [pop]                                            Starboy
# 44         100  [pop]                       (It Goes Like) Nanana [Edit]
# 45         100  [pop]                MAÑANA SERÁ BONITO (BICHOTA SEASON)
# 46         100  [pop]                                        El Comienzo
# 47         100  [pop]                                               1989
# 48         100  [pop]                                               GUTS
# 49         100  [pop]                                               1989

# %%
artists_names = df['Artist Name'].unique()

# %%
print(artists_names)
# Out:
# ['Doja Cat' 'Jung Kook' 'Olivia Rodrigo' 'Taylor Swift' 'KAROL G'
#  'Myke Towers' 'Dua Lipa' 'Billie Eilish' 'Quevedo' 'V' 'Gunna'
#  'David Kushner' 'Peso Pluma' 'Dave' 'Arctic Monkeys' 'Harry Styles' 'SZA'
#  'Miley Cyrus' 'Kenya Grace' 'Zach Bryan' 'Calle 24' 'NewJeans' 'Feid'
#  'Bad Bunny' 'cassö' 'Yng Lvcas' 'Anirudh Ravichander' 'Nicki Minaj'
#  'Carin Leon' 'The Weeknd' 'Jhayco' 'Jasleen Royal' 'Peggy Gou'
#  'Grupo Frontera']

# %%
tracks_names = df['Track Name']

# %%
list(tracks_names)
# Out:
# ['Paint The Town Red',
#  'Seven (feat. Latto) (Explicit Ver.)',
#  'vampire',
#  'Cruel Summer',
#  'bad idea right?',
#  'get him back!',
#  'QLONA',
#  'LALA',
#  'all-american bitch',
#  'Dance The Night - From Barbie The Album',
#  'What Was I Made For? [From The Motion Picture "Barbie"]',
#  'Columbia',
#  'Slow Dancing',
#  'fukumean',
#  'the grudge',
#  'making the bed',
#  'ballad of a homeschooled girl',
#  'logical',
#  'lacy',
#  'Daylight',
#  'LADY GAGA',
#  'love is embarrassing',
#  'Sprinter',
#  'I Wanna Be Yours',
#  'As It Was',
#  'Love Me Again',
#  'Kill Bill',
#  'Flowers',
#  'Strangers',
#  'I Remember Everything (feat. Kacey Musgraves)',
#  'Que Onda',
#  'Super Shy',
#  'pretty isn’t pretty',
#  'Classy 101',
#  'WHERE SHE GOES',
#  'Prada',
#  'La Bebe - Remix',
#  'Chaleya',
#  'Barbie World (with Aqua) [From Barbie The Album]',
#  'Primera Cita',
#  'Popular (with Playboi Carti & Madonna) - Music from the HBO Original Series',
#  'Holanda',
#  'Heeriye (feat. Arijit Singh)',
#  'Starboy',
#  '(It Goes Like) Nanana - Edit',
#  'MI EX TENÍA RAZÓN',
#  'un x100to',
#  'Style',
#  'teenage dream',
#  'Blank Space']

# %%
len(tracks_names)
# Out:
# 50

# %%
acoustic = []
dance = []
energy = []
instrumental = []
liveness = []
loudness = []
speech = []
tempo = []
valence = []
popularity = []
duration = []
#plays = []

for i in track_uris:
    feat = sp.audio_features(i)[0]
    acoustic.append(feat['acousticness'])
    dance.append(feat['danceability'])
    energy.append(feat['energy'])
    speech.append(feat['speechiness'])
    instrumental.append(feat['instrumentalness'])
    loudness.append(feat['loudness'])
    tempo.append(feat['tempo'])
    liveness.append(feat['liveness'])
    valence.append(feat['valence'])
    popu = sp.track(i)
    popularity.append(popu['popularity'])
    duration.append(feat['duration_ms'])
    #plays.append(popu['plays'])

# %%
len(tname)
# Out:
# 50

# %%
ari = pd.DataFrame({'Track Name': tname,
                    'Track_URI': trackuri,
                    'Artist Name': artname,
                    'Artist URI': artisturi,
                    'Artist Info': artistinfo,
                    'Artist Pop': artpop,
                    'Album': albumname,
                    'Genres': artgenres,
                    'dance':dance,
                    'acoustic':acoustic,
                    'energy':energy,
                    'instrumental':instrumental,
                    'liveness':liveness,
                    'loudness':loudness,
                    'speech':speech,
                    'tempo':tempo,
                    'valence':valence,
                    'track_popular':popularity,
                    'duration_ms':duration,                  
})
ari
# Out:
#                                            Track Name  \
# 0                                  Paint The Town Red
# 1                 Seven (feat. Latto) (Explicit Ver.)
# 2                                             vampire
# 3                                        Cruel Summer
# 4                                     bad idea right?
# 5                                       get him back!
# 6                                               QLONA
# 7                                                LALA
# 8                                  all-american bitch
# 9             Dance The Night - From Barbie The Album
# 10  What Was I Made For? [From The Motion Picture ...
# 11                                           Columbia
# 12                                       Slow Dancing
# 13                                           fukumean
# 14                                         the grudge
# 15                                     making the bed
# 16                      ballad of a homeschooled girl
# 17                                            logical
# 18                                               lacy
# 19                                           Daylight
# 23  spotify:artist:7Ln80lUS6He07XvHI8qqHH
# 24  spotify:artist:6KImCVD70vtIoJWnq6nGn3
# 25  spotify:artist:3JsHnjpbhX4SnySpvpa9DK
# 26  spotify:artist:7tYKF4w9nC0nq9CsPZTHyP
# 27  spotify:artist:5YGY8feqx7naU7z4HrwZM6
# 28  spotify:artist:7uMDnSZyUYNBPLhPMNuaM2
# 29  spotify:artist:40ZNYROS4zLfyyBSs2PGe2
# 30  spotify:artist:6dLuQ5qXxIuWc5urxfIiZR
# 31  spotify:artist:6HvZYsbFfjnjFrWF950C9d
# 32  spotify:artist:1McMsnEElThX1knmY4oliG
# 33  spotify:artist:2LRoIwlKmHjgvigdNGBHNo
# 34  spotify:artist:4q3ewBCX7sLwd24euuV69X
# 35  spotify:artist:5wCmhq5J2hPwL2r0eKurxn
# 36  spotify:artist:1NNRWkhwmcXRimFYSBpB1y
# 37  spotify:artist:4zCH9qm4R2DADamUHMCa6O
# 38  spotify:artist:0hCNtLu0JehylgoiP8L4Gh
# 39  spotify:artist:66ihevNkSYNzRAl44dx6jJ
# 40  spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ
# 41  spotify:artist:6nVcHLIgY5pE2YCl8ubca1
# 42  spotify:artist:74OaRjmyh0XyRZsQQQ5l7c
# 43  spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ
# 44  spotify:artist:2mLA48B366zkELXYx7hcDN
# 45  spotify:artist:790FomKkXshlbRYZFtlgla
# 46  spotify:artist:6XkjpgcEsYab502Vr1bBeW
# 47  spotify:artist:06HL4z0CvFAxyc27GXpf02
# 48  spotify:artist:1McMsnEElThX1knmY4oliG
# 49  spotify:artist:06HL4z0CvFAxyc27GXpf02
#
#                                           Artist Info  Artist Pop  \
# 0   {'external_urls': {'spotify': 'https://open.sp...         100
# 1   {'external_urls': {'spotify': 'https://open.sp...         100
# 2   {'external_urls': {'spotify': 'https://open.sp...         100
# 3   {'external_urls': {'spotify': 'https://open.sp...         100
# 4   {'external_urls': {'spotify': 'https://open.sp...         100
# 5   {'external_urls': {'spotify': 'https://open.sp...         100
# 6   {'external_urls': {'spotify': 'https://open.sp...         100
# 7   {'external_urls': {'spotify': 'https://open.sp...         100
# 8   {'external_urls': {'spotify': 'https://open.sp...         100
# 9   {'external_urls': {'spotify': 'https://open.sp...         100
# 10  {'external_urls': {'spotify': 'https://open.sp...         100
# 11  {'external_urls': {'spotify': 'https://open.sp...         100
# 12  {'external_urls': {'spotify': 'https://open.sp...         100
# 13  {'external_urls': {'spotify': 'https://open.sp...         100
# 14  {'external_urls': {'spotify': 'https://open.sp...         100
# 15  {'external_urls': {'spotify': 'https://open.sp...         100
# 16  {'external_urls': {'spotify': 'https://open.sp...         100
# 17  {'external_urls': {'spotify': 'https://open.sp...         100
# 18  {'external_urls': {'spotify': 'https://open.sp...         100
# 19  {'external_urls': {'spotify': 'https://open.sp...         100
# 20  {'external_urls': {'spotify': 'https://open.sp...         100
# 21  {'external_urls': {'spotify': 'https://open.sp...         100
# 22  {'external_urls': {'spotify': 'https://open.sp...         100
# 23  {'external_urls': {'spotify': 'https://open.sp...         100
# 24  {'external_urls': {'spotify': 'https://open.sp...         100
# 25  {'external_urls': {'spotify': 'https://open.sp...         100
# 26  {'external_urls': {'spotify': 'https://open.sp...         100
# 27  {'external_urls': {'spotify': 'https://open.sp...         100
# 28  {'external_urls': {'spotify': 'https://open.sp...         100
# 29  {'external_urls': {'spotify': 'https://open.sp...         100
# 30  {'external_urls': {'spotify': 'https://open.sp...         100
# 31  {'external_urls': {'spotify': 'https://open.sp...         100
# 32  {'external_urls': {'spotify': 'https://open.sp...         100
# 33  {'external_urls': {'spotify': 'https://open.sp...         100
# 34  {'external_urls': {'spotify': 'https://open.sp...         100
# 35  {'external_urls': {'spotify': 'https://open.sp...         100
# 36  {'external_urls': {'spotify': 'https://open.sp...         100
# 37  {'external_urls': {'spotify': 'https://open.sp...         100
# 38  {'external_urls': {'spotify': 'https://open.sp...         100
# 39  {'external_urls': {'spotify': 'https://open.sp...         100
# 40  {'external_urls': {'spotify': 'https://open.sp...         100
# 41  {'external_urls': {'spotify': 'https://open.sp...         100
# 42  {'external_urls': {'spotify': 'https://open.sp...         100
# 43  {'external_urls': {'spotify': 'https://open.sp...         100
# 44  {'external_urls': {'spotify': 'https://open.sp...         100
# 45  {'external_urls': {'spotify': 'https://open.sp...         100
# 46  {'external_urls': {'spotify': 'https://open.sp...         100
# 47  {'external_urls': {'spotify': 'https://open.sp...         100
# 48  {'external_urls': {'spotify': 'https://open.sp...         100
# 49  {'external_urls': {'spotify': 'https://open.sp...         100
#
#                                                 Album Genres  dance  acoustic  \
# 0                                  Paint The Town Red  [pop]  0.868   0.26900
# 1                                 Seven (feat. Latto)  [pop]  0.802   0.31100
# 2                                                GUTS  [pop]  0.511   0.17700
# 3                                               Lover  [pop]  0.552   0.11700
# 4                                                GUTS  [pop]  0.627   0.00193
# 5                                                GUTS  [pop]  0.546   0.01350
# 6                 MAÑANA SERÁ BONITO (BICHOTA SEASON)  [pop]  0.841   0.52000
# 7                                      LA VIDA ES UNA  [pop]  0.708   0.07390
# 8                                                GUTS  [pop]  0.430   0.25400
# 9             Dance The Night (From Barbie The Album)  [pop]  0.671   0.02070
# 10  What Was I Made For? [From The Motion Picture ...  [pop]  0.444   0.95900
# 11                                           Columbia  [pop]  0.668   0.36900
# 12                                       Slow Dancing  [pop]  0.566   0.21700
# 13                                   a Gift & a Curse  [pop]  0.847   0.11900
# 14                                               GUTS  [pop]  0.548   0.91600
# 15                                               GUTS  [pop]  0.537   0.34600
# 16                                               GUTS  [pop]  0.385   0.05570
# 17                                               GUTS  [pop]  0.499   0.85300
# 18                                               GUTS  [pop]  0.455   0.80300
# 19                                           Daylight  [pop]  0.508   0.83000
# 20                                            GÉNESIS  [pop]  0.646   0.21600
# 21                                               GUTS  [pop]  0.520   0.00261
# 22                                           Sprinter  [pop]  0.916   0.18600
# 23                                                 AM  [pop]  0.464   0.13600
# 24                                      Harry's House  [pop]  0.520   0.34200
# 25                                            Layover  [pop]  0.633   0.18300
# 26                                                SOS  [pop]  0.644   0.05210
# 27                            Endless Summer Vacation  [pop]  0.707   0.06320
# 28                                          Strangers  [pop]  0.628   0.70100
# 29                                         Zach Bryan  [pop]  0.429   0.55400
# 26  0.7350      0.144000    0.1610    -5.747  0.0391   88.980    0.418
# 27  0.6810      0.000005    0.0322    -4.325  0.0668  117.999    0.646
# 28  0.5230      0.002740    0.2190    -8.307  0.0946  169.982    0.416
# 29  0.4530      0.000002    0.1020    -7.746  0.0459   77.639    0.155
# 30  0.9440      0.000001    0.1380    -4.863  0.0408  124.934    0.937
# 31  0.8170      0.000034    0.1460    -6.018  0.0748  149.921    0.515
# 32  0.8540      0.000002    0.0798    -4.338  0.0561  123.926    0.594
# 33  0.6580      0.000000    0.1200    -4.790  0.1590  100.065    0.672
# 34  0.8000      0.629000    0.1120    -4.019  0.0614  143.978    0.234
# 35  0.7170      0.000002    0.1130    -5.804  0.0375  141.904    0.422
# 36  0.4790      0.000001    0.0756    -5.678  0.3330  169.922    0.559
# 37  0.8450      0.010700    0.1310    -5.280  0.0852   95.047    0.439
# 38  0.5800      0.000127    0.2330    -8.393  0.2470  144.072    0.753
# 39  0.3950      0.000068    0.0969    -7.805  0.0634  157.795    0.488
# 40  0.6780      0.000037    0.4120    -6.276  0.1890   99.029    0.852
# 41  0.7590      0.000000    0.1250    -3.627  0.0502  107.961    0.244
# 42  0.4940      0.003840    0.0759    -9.628  0.0256  105.007    0.558
# 43  0.5870      0.000006    0.1370    -7.015  0.2760  186.003    0.486
# 44  0.8760      0.188000    0.0823    -5.681  0.0352  129.998    0.964
# 45  0.7250      0.000000    0.2110    -4.945  0.0587  159.845    0.795
# 46  0.7200      0.000000    0.2710    -4.089  0.0458   83.827    0.542
# 47  0.7860      0.001600    0.1170    -5.572  0.0383   95.019    0.456
# 48  0.2290      0.000000    0.1090   -10.208  0.0362  135.820    0.104
# 49  0.6780      0.000002    0.1300    -5.421  0.0644   96.006    0.583
#
#     track_popular  duration_ms
# 0             100       231750
# 1              99       185427
# 2              88       219724
# 3              99       178427
# 4              88       184784
# 5              89       211141
# 6              91       172798
# 7              99       197920
# 8              88       165834
# 9              97       176579
# 10             98       222370
# 11             97       186000
# 12              0       190872
# 13             96       125040
# 14             87       189386
# 15             86       198867
# 16             86       203369
# 17             86       231907
# 18             86       177212
# 19             96       212954
# 20             94       212878
# 21             86       154517
# 22             95       226383
# 23             94       183956
# 24             92       167303
# 25             94       182293
# 26             92       153947
# 27             95       200455
# 28             88       172965
# 29             91       227196
# 30             88       191467
# 31             94       154667
# 32             85       199422
# 33             94       195987
# 34             95       231704
# 35             91       132359
# 36             94       234353
# 37             72       200374
# 38             94       109750
# 39             86       186456
# 40             93       215467
# 41             92       231693
# 42             90       194857
# 43             92       230453
# 44             94       231545
# 45             88       154375
# 46             80       194563
# 47             83       231000
# 48             84       222358
# 49             83       231827

# %%
#ari.to_csv("ari_df.csv", index=True)

# %%
ari_sort_pop = ari.sort_values(by='track_popular', ascending=False)
ari_sort_pop
# Out:
#                                            Track Name  \
# 0                                  Paint The Town Red
# 7                                                LALA
# 1                 Seven (feat. Latto) (Explicit Ver.)
# 3                                        Cruel Summer
# 10  What Was I Made For? [From The Motion Picture ...
# 11                                           Columbia
spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ
# 41  spotify:artist:6nVcHLIgY5pE2YCl8ubca1
# 24  spotify:artist:6KImCVD70vtIoJWnq6nGn3
# 43  spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ
# 26  spotify:artist:7tYKF4w9nC0nq9CsPZTHyP
# 35  spotify:artist:5wCmhq5J2hPwL2r0eKurxn
# 6   spotify:artist:790FomKkXshlbRYZFtlgla
# 29  spotify:artist:40ZNYROS4zLfyyBSs2PGe2
# 42  spotify:artist:74OaRjmyh0XyRZsQQQ5l7c
# 5   spotify:artist:1McMsnEElThX1knmY4oliG
# 28  spotify:artist:7uMDnSZyUYNBPLhPMNuaM2
# 4   spotify:artist:1McMsnEElThX1knmY4oliG
# 30  spotify:artist:6dLuQ5qXxIuWc5urxfIiZR
# 8   spotify:artist:1McMsnEElThX1knmY4oliG
# 2   spotify:artist:1McMsnEElThX1knmY4oliG
# 45  spotify:artist:790FomKkXshlbRYZFtlgla
# 14  spotify:artist:1McMsnEElThX1knmY4oliG
# 39  spotify:artist:66ihevNkSYNzRAl44dx6jJ
# 18  spotify:artist:1McMsnEElThX1knmY4oliG
# 21  spotify:artist:1McMsnEElThX1knmY4oliG
# 15  spotify:artist:1McMsnEElThX1knmY4oliG
# 16  spotify:artist:1McMsnEElThX1knmY4oliG
# 17  spotify:artist:1McMsnEElThX1knmY4oliG
# 32  spotify:artist:1McMsnEElThX1knmY4oliG
# 48  spotify:artist:1McMsnEElThX1knmY4oliG
# 47  spotify:artist:06HL4z0CvFAxyc27GXpf02
# 49  spotify:artist:06HL4z0CvFAxyc27GXpf02
# 46  spotify:artist:6XkjpgcEsYab502Vr1bBeW
# 37  spotify:artist:4zCH9qm4R2DADamUHMCa6O
# 12  spotify:artist:0p7Z7ADLlzQhAoSv8gLqze
#
#                                           Artist Info  Artist Pop  \
# 0   {'external_urls': {'spotify': 'https://open.sp...         100
# 7   {'external_urls': {'spotify': 'https://open.sp...         100
# 1   {'external_urls': {'spotify': 'https://open.sp...         100
# 3   {'external_urls': {'spotify': 'https://open.sp...         100
# 10  {'external_urls': {'spotify': 'https://open.sp...         100
# 11  {'external_urls': {'spotify': 'https://open.sp...         100
# 9   {'external_urls': {'spotify': 'https://open.sp...         100
# 19  {'external_urls': {'spotify': 'https://open.sp...         100
# 13  {'external_urls': {'spotify': 'https://open.sp...         100
# 34  {'external_urls': {'spotify': 'https://open.sp...         100
# 27  {'external_urls': {'spotify': 'https://open.sp...         100
# 22  {'external_urls': {'spotify': 'https://open.sp...         100
# 33  {'external_urls': {'spotify': 'https://open.sp...         100
# 36  {'external_urls': {'spotify': 'https://open.sp...         100
# 38  {'external_urls': {'spotify': 'https://open.sp...         100
# 31  {'external_urls': {'spotify': 'https://open.sp...         100
# 44  {'external_urls': {'spotify': 'https://open.sp...         100
# 23  {'external_urls': {'spotify': 'https://open.sp...         100
# 20  {'external_urls': {'spotify': 'https://open.sp...         100
# 25  {'external_urls': {'spotify': 'https://open.sp...         100
# 40  {'external_urls': {'spotify': 'https://open.sp...         100
# 41  {'external_urls': {'spotify': 'https://open.sp...         100
# 24  {'external_urls': {'spotify': 'https://open.sp...         100
# 43  {'external_urls': {'spotify': 'https://open.sp...         100
# 26  {'external_urls': {'spotify': 'https://open.sp...         100
# 35  {'external_urls': {'spotify': 'https://open.sp...         100
# 6   {'external_urls': {'spotify': 'https://open.sp...         100
# 29  {'external_urls': {'spotify': 'https://open.sp...         100
# 42  {'external_urls': {'spotify': 'https://open.sp...         100
# 5   {'external_urls': {'spotify': 'https://open.sp...         100
# 28  {'external_urls': {'spotify': 'https://open.sp...         100
# 4   {'external_urls': {'spotify': 'https://open.sp...         100
# 30  {'external_urls': {'spotify': 'https://open.sp...         100
# 8   {'external_urls': {'spotify': 'https://open.sp...         100
# 2   {'external_urls': {'spotify': 'https://open.sp...         100
# 45  {'external_urls': {'spotify': 'https://open.sp...         100
# 14  {'external_urls': {'spotify': 'https://open.sp...         100
# 39  {'external_urls': {'spotify': 'https://open.sp...         100
# 18  {'external_urls': {'spotify': 'https://open.sp...         100
# 21  {'external_urls': {'spotify': 'https://open.sp...         100
# 15  {'external_urls': {'spotify': 'https://open.sp...         100
# 16  {'external_urls': {'spotify': 'https://open.sp...         100
# 17  {'external_urls': {'spotify': 'https://open.sp...         100
# 32  {'external_urls': {'spotify': 'https://open.sp...         100
# 48  {'external_urls': {'spotify': 'https://open.sp...         100
# 47  {'external_urls': {'spotify': 'https://open.sp...         100
# 49  {'external_urls': {'spotify': 'https://open.sp...         100
# 46  {'external_urls': {'spotify': 'https://open.sp...         100
# 37  {'external_urls': {'spotify': 'https://open.sp...         100
# 12  {'external_urls': {'spotify': 'https://open.sp...         100
#
#                                                 Album Genres  dance  acoustic  \
# 0                                  Paint The Town Red  [pop]  0.868   0.26900
# 7                                      LA VIDA ES UNA  [pop]  0.708   0.07390
# 1                                 Seven (feat. Latto)  [pop]  0.802   0.31100
# 3                                               Lover  [pop]  0.552   0.11700
# 10  What Was I Made For? [From The Motion Picture ...  [pop]  0.444   0.95900
# 11                                           Columbia  [pop]  0.668   0.36900
# 9             Dance The Night (From Barbie The Album)  [pop]  0.671   0.02070
# 19                                           Daylight  [pop]  0.508   0.83000
# 13                                   a Gift & a Curse  [pop]  0.847   0.11900
# 34                                     WHERE SHE GOES  [pop]  0.652   0.14300
# 27                            Endless Summer Vacation  [pop]  0.707   0.06320
# 22                                           Sprinter  [pop]  0.916   0.18600
# 33                                         Classy 101  [pop]  0.859   0.14500
# 36                                    La Bebe (Remix)  [pop]  0.812   0.21300
# 38   Barbie World (with Aqua) [From Barbie The Album]  [pop]  0.770   0.51900
# 31                               NewJeans 'Super Shy'  [pop]  0.776   0.18000
# 44                       (It Goes Like) Nanana [Edit]  [pop]  0.671   0.12000
# 23                                                 AM  [pop]  0.464   0.13600
# 20                                            GÉNESIS  [pop]  0.646   0.21600
# 25                                            Layover  [pop]  0.633   0.18300
# 40       Popular (Music from the HBO Original Series)  [pop]  0.855   0.05690
# 41                                            Holanda  [pop]  0.831   0.27700
# 24                                      Harry's House  [pop]  0.520   0.34200
# 43                                            Starboy  [pop]  0.679   0.14100
# 26                                                SOS  [pop]  0.644   0.05210
# 35                                              Prada  [pop]  0.638   0.00100
# 6                 MAÑANA SERÁ BONITO (BICHOTA SEASON)  [pop]  0.841   0.52000
# 29                                         Zach Bryan  [pop]  0.429   0.55400
# 42                       Heeriye (feat. Arijit Singh)  [pop]  0.728   0.51600
# 5                                                GUTS  [pop]  0.546   0.01350
# 28                                          Strangers  [pop]  0.628   0.70100
# 4                                                GUTS  [pop]  0.627   0.00193
# 30                                           Que Onda  [pop]  0.808   0.18300
# 8                                                GUTS  [pop]  0.430   0.25400
# 2                                                GUTS  [pop]  0.511   0.17700
# 45                MAÑANA SERÁ BONITO (BICHOTA SEASON)  [pop]  0.634   0.07760
# 14                                               GUTS  [pop]  0.548   0.91600
# 39                                  Colmillo De Leche  [pop]  0.535   0.59700
# 18                                               GUTS  [pop]  0.455   0.80300
# 21                                               GUTS  [pop]  0.520   0.00261
# 15                                               GUTS  [pop]  0.537   0.34600
# 16                                               GUTS  [pop]  0.385   0.05570
# 17                                               GUTS  [pop]  0.499   0.85300
# 32                                               GUTS  [pop]  0.554   0.00394
# 48                                               GUTS  [pop]  0.422   0.81600
# 47                                               1989  [pop]  0.598   0.00253
# 49                                               1989  [pop]  0.753   0.08500
# 46                                        El Comienzo  [pop]  0.571   0.21300
# 37                                              Jawan  [pop]  0.575   0.39300
# 12                                       Slow Dancing  [pop]  0.566   0.21700
#
#     energy  instrumental  liveness  loudness  speech    tempo  valence  \
# 0   0.5380      0.000003    0.0901    -8.603  0.1740   99.968    0.732
# 7   0.7370      0.001620    0.0955    -4.045  0.0436   91.986    0.607
# 1   0.8320      0.000000    0.0815    -4.107  0.0434  124.997    0.890
# 3   0.7020      0.000021    0.1050    -5.707  0.1570  169.994    0.564
# 10  0.0911      0.000001    0.0980   -17.665  0.0307   78.403    0.142
# 11  0.7120      0.000021    0.1080    -5.927  0.0381  100.020    0.264
# 9   0.8450      0.000000    0.3290    -4.930  0.0480  110.056    0.775
# 19  0.4300      0.000441    0.0930    -9.475  0.0335  130.090    0.324
# 13  0.6220      0.000000    0.2850    -6.747  0.0903  130.001    0.220
# 34  0.8000      0.629000    0.1120    -4.019  0.0614  143.978    0.234
# 27  0.6810      0.000005    0.0322    -4.325  0.0668  117.999    0.646
# 22  0.5830      0.000000    0.0798    -8.067  0.2410  141.095    0.661
# 33  0.6580      0.000000    0.1200    -4.790  0.1590  100.065    0.672
# 36  0.4790      0.000001    0.0756    -5.678  0.3330  169.922    0.559
# 38  0.5800      0.000127    0.2330    -8.393  0.2470  144.072    0.753
# 31  0.8170      0.000034    0.1460    -6.018  0.0748  149.921    0.515
# 44  0.8760      0.188000    0.0823    -5.681  0.0352  129.998    0.964
# 23  0.4170      0.022000    0.0974    -9.345  0.0256   67.528    0.479
# 20  0.7360      0.000000    0.4150    -7.118  0.0449  140.098    0.873
# 25  0.6070      0.000001    0.1670    -6.182  0.0532   74.029    0.363
# 40  0.6780      0.000037    0.4120    -6.276  0.1890   99.029    0.852
# ['Track Name',
#  'Track_URI',
#  'Artist Name',
#  'Artist URI',
#  'Artist Info',
#  'Artist Pop',
#  'Album',
#  'Genres',
#  'dance',
#  'acoustic',
#  'energy',
#  'instrumental',
#  'liveness',
#  'loudness',
#  'speech',
#  'tempo',
#  'valence',
#  'track_popular',
#  'duration_ms']

# %%
# total duration & average popularity of the playlist's tracks
total_duration = ari['duration_ms'].sum()
avg_popularity = ari['track_popular'].mean()
print (total_duration, avg_popularity)
# Out:
# 9718931 88.98

# %%
top_artists = ari_sort_pop['Artist Name'].value_counts().head(10)
top_artists
# Out:
# Olivia Rodrigo    12
# Taylor Swift       3
# V                  2
# KAROL G            2
# The Weeknd         2
# Jhayco             1
# Harry Styles       1
# SZA                1
# cassö              1
# Doja Cat           1
# Name: Artist Name, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
# display tracks popularity

ari_sort_pop.plot(kind='bar',
        x='Track Name',
        y='track_popular',
        color='green')
  
# set the title
plt.title('Track Popularity')
  
# show the plot
plt.show()

# %%
X = ari_sort_pop[["dance",
                "acoustic",
                "energy",
                "instrumental",
                "liveness", 
                "speech",
                "tempo",
                "valence",
                "duration_ms"]]

y = ari_sort_pop["track_popular"]
import statsmodels.api as sm
model = sm.OLS(y,X)
results = model.fit()
results.pvalues
#results.summary()
# Out:
# dance           0.006608
# acoustic        0.105334
# energy          0.325933
# instrumental    0.996227
# liveness        0.199922
# speech          0.519200
# tempo           0.548812
# valence         0.573988
# duration_ms     0.017772
# dtype: float64

# %% [markdown]
# Danceability and duration can be considered as significant.

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:          track_popular   R-squared (uncentered):                   0.973
# Model:                            OLS   Adj. R-squared (uncentered):              0.967
# Method:                 Least Squares   F-statistic:                              164.9
# Date:                Fri, 15 Sep 2023   Prob (F-statistic):                    2.82e-29
# Time:                        15:25:33   Log-Likelihood:                         -205.56
# No. Observations:                  50   AIC:                                      429.1
# Df Residuals:                      41   BIC:                                      446.3
# Df Model:                           9
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# dance           58.3658     20.396      2.862      0.007      17.175      99.557
# acoustic        20.3251     12.273      1.656      0.105      -4.460      45.110
# energy          20.3340     20.452      0.994      0.326     -20.969      61.637
# instrumental    -0.1271     26.714     -0.005      0.996     -54.077      53.822
# liveness        29.4807     22.629      1.303      0.200     -16.220      75.181
# speech         -26.7282     41.109     -0.650      0.519    -109.749      56.293
# tempo            0.0503      0.083      0.605      0.549      -0.118       0.218
# valence         -8.2583     14.572     -0.567      0.574     -37.687      21.170
# duration_ms      0.0001   5.85e-05      2.470      0.018    2.64e-05       0.000
# ==============================================================================
# Omnibus:                       67.493   Durbin-Watson:                   1.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              732.303
# Skew:                          -3.398   Prob(JB):                    9.60e-160
# Kurtosis:                      20.473   Cond. No.                     3.78e+06
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 3.78e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# R-squared is 0.973, indicating a perfect fit of the model, p-values of acoustic,
# energy, instrumental, liveness, speech, tempo, valence are > 0.05, these parameters are insignificant. 
# Then we'll repeat analysis excluding these factors.

X = ari_sort_pop[["dance",
                "duration_ms"]]

y = ari_sort_pop["track_popular"]
import statsmodels.api as sm
model = sm.OLS(y,X)
results = model.fit()
results.pvalues
#results.summary()
# Out:
# dance          0.000042
# duration_ms    0.000002
# dtype: float64

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:          track_popular   R-squared (uncentered):                   0.967
# Model:                            OLS   Adj. R-squared (uncentered):              0.966
# Method:                 Least Squares   F-statistic:                              709.6
# Date:                Fri, 15 Sep 2023   Prob (F-statistic):                    2.26e-36
# Time:                        15:27:09   Log-Likelihood:                         -210.47
# No. Observations:                  50   AIC:                                      424.9
# Df Residuals:                      48   BIC:                                      428.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# dance          61.8652     13.722      4.509      0.000      34.276      89.454
# duration_ms     0.0002   4.55e-05      5.484      0.000       0.000       0.000
# ==============================================================================
# Omnibus:                       53.605   Durbin-Watson:                   1.139
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              338.394
# Skew:                          -2.685   Prob(JB):                     3.30e-74
# Kurtosis:                      14.558   Cond. No.                     1.15e+06
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.15e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
results.mse_model
# Out:
# 196088.75434712044

# %%
results.resid
# Out:
# 0    -11.479483
# 7      5.853529
# 1      3.152988
# 3     20.364542
# 10    15.090001
# 11     9.300061
# 9     11.463333
# 19    11.478251
# 13    12.424896
# 34    -3.105134
# 27     1.283361
# 22   -18.110898
# 33    -8.006174
# 36   -14.664019
# 38    19.000657
# 31     7.430645
# 44    -5.240930
# 23    19.430174
# 20     0.959803
# 25     9.389581
# 40   -13.615516
# 41   -17.176260
# 24    18.117692
# 43    -7.463592
# 26    13.776361
# 35    18.529928
# 6     -4.111060
# 29     7.814748
# 42    -3.620100
# 5      2.579395
# 28     6.024588
# 4      3.139710
# 30    -9.724111
# 8     20.051814
# 2      1.604741
# 45    10.288303
# 14     5.879677
# 39     6.414440
# 18    13.668392
# 21    15.305530
# 15     3.196367
# 16    11.477425
# 17    -2.690373
# 32     1.006285
# 48     2.454027
# 47   -11.588891
# 49   -21.384184
# 46    -3.833965
# 37   -13.530239
# 12   -82.604390
# dtype: float64

# %%
import plotly.graph_objects as go

# %%
fig = go.Figure(data=go.Scatter(x=X,y=y,mode="markers",name="pop"))

# %%
fig.add_scatter(x=X,y=results.fittedvalues,name="Model")
# Out:
# <div>                            <div id="8eee29b4-58f4-407e-a5fd-90efda0bd16e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8eee29b4-58f4-407e-a5fd-90efda0bd16e")) {                    Plotly.newPlot(                        "8eee29b4-58f4-407e-a5fd-90efda0bd16e",                        [{"mode":"markers","name":"pop","x":[[0.868,231750.0],[0.708,197920.0],[0.802,185427.0],[0.552,178427.0],[0.444,222370.0],[0.668,186000.0],[0.671,176579.0],[0.508,212954.0],[0.847,125040.0],[0.652,231704.0],[0.707,200455.0],[0.916,226383.0],[0.859,195987.0],[0.812,234353.0],[0.77,109750.0],[0.776,154667.0],[0.671,231545.0],[0.464,183956.0],[0.646,212878.0],[0.633,182293.0],[0.855,215467.0],[0.831,231693.0],[0.52,167303.0],[0.679,230453.0],[0.644,153947.0],[0.638,132359.0],[0.841,172798.0],[0.429,227196.0],[0.728,194857.0],[0.546,211141.0],[0.628,172965.0],[0.627,184784.0],[0.808,191467.0],[0.43,165834.0],[0.511,219724.0],[0.634,154375.0],[0.548,189386.0],[0.535,186456.0],[0.455,177212.0],[0.52,154517.0],[0.537,198867.0],[0.385,203369.0],[0.499,231907.0],[0.554,199422.0],[0.422,222358.0],[0.598,231000.0],[0.753,231827.0],[0.571,194563.0],[0.575,200374.0],[0.566,190872.0]],"y":[100,99,99,99,98,97,97,96,96,95,95,95,94,94,94,94,94,94,94,94,93,92,92,92,92,91,91,91,90,89,88,88,88,88,88,88,87,86,86,86,86,86,86,85,84,83,83,80,72,0],"type":"scatter"},{"name":"Model","x":[[0.868,231750.0],[0.708,197920.0],[0.802,185427.0],[0.552,178427.0],[0.444,222370.0],[0.668,186000.0],[0.671,176579.0],[0.508,212954.0],[0.847,125040.0],[0.652,231704.0],[0.707,200455.0],[0.916,226383.0],[0.859,195987.0],[0.812,234353.0],[0.77,109750.0],[0.776,154667.0],[0.671,231545.0],[0.464,183956.0],[0.646,212878.0],[0.633,182293.0],[0.855,215467.0],[0.831,231693.0],[0.52,167303.0],[0.679,230453.0],[0.644,153947.0],[0.638,132359.0],[0.841,172798.0],[0.429,227196.0],[0.728,194857.0],[0.546,211141.0],[0.628,172965.0],[0.627,184784.0],[0.808,191467.0],[0.43,165834.0],[0.511,219724.0],[0.634,154375.0],[0.548,189386.0],[0.535,186456.0],[0.455,177212.0],[0.52,154517.0],[0.537,198867.0],[0.385,203369.0],[0.499,231907.0],[0.554,199422.0],[0.422,222358.0],[0.598,231000.0],[0.753,231827.0],[0.571,194563.0],[0.575,200374.0],[0.566,190872.0]],"y":[111.47948291086712,93.14647123179124,95.84701198511955,78.63545775757083,82.9099987466625,87.69993896719936,85.53666673777352,84.52174943851061,83.57510423119095,98.10513403014286,93.71663872196584,113.11089765956541,102.00617372719344,108.66401913855506,74.99934309880874,86.56935538986707,99.24093026630368,74.56982584728435,93.04019650753924,84.61041876932606,106.61551634656215,109.1762596660077,73.88230772941247,99.46359151991393,78.22363867979873,72.47007226177246,95.11105967485106,83.18525161371454,93.62009995518116,86.42060469191232,81.97541205438293,84.860290140178,97.72411132637858,67.94818621223396,86.3952586883707,77.7116968792555,81.12032289037319,79.58556039579247,72.3316078715286,70.6944695480679,82.80363298998455,74.52257495160865,88.69037314475175,83.99371515926032,81.54597279753295,94.58889094099723,104.38418442825423,83.8339650186816,85.5302391241984,82.60438954323787],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0 ...

# %%
ari_sort_pop.plot(kind='scatter',
        x='track_popular',
        y='duration_ms',
        color='red')
  
# set the title
plt.title('Popularity Dependence on Track Duration')
  
# show the plot
plt.show()

# %%
ari_sort_pop.plot(kind='scatter',
        x='track_popular',
        y='dance',
        color='red')
  
# set the title
plt.title('Popularity Dependence on Track Danceability')
  
# show the plot
plt.show()

# %%
ari_sort_pop.plot(kind='scatter',
        x='track_popular',
        y='loudness',
        color='red')
  
# set the title
plt.title('Popularity Dependence on Track Loudness')
  
# show the plot
plt.show()

# %%
ari_sort_pop.plot(kind='scatter',
        x='track_popular',
        y='energy',
        color='red')
  
# set the title
plt.title('Popularity Dependence on Track Energy')
  
# show the plot
plt.show()

# %%
# import numpy as np #?????
# np.asarray(data)

# %%
# import mysql.connector
# connection = mysql.connector.connect(user="root",
#                                      password="",
#                                      host="localhost",
#                                      database="db_from_spotify")

# cursor = connection.cursor()
# import sqlalchemy
# engine = sqlalchemy.create_engine('sqlite:///db_from_spotify.db')
# track_dataframe.to_sql('db_from_spotify',engine, if_exists='append', index=False)
